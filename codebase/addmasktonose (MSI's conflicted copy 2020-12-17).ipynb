# %% [markdown]
# # the first cell creats path files to save frames from R.avi (whisker right left side)

# %%
Mainfolder = 'D:\\videos\\ar32\\2020_11_24\\'
from pathlib import Path
import os
from IPython.display import clear_output
clear_output(wait=True)
XfilesR = [os.path.join(Mainfolder,f) for f in os.listdir(Mainfolder) if f.endswith('R.avi') and not f.startswith('Mirror')] # find all files with R.avi as file name
Xfiles2 = [Path(f) for f in XfilesR] # make each file name path to extract the parents and anme
Xfiles3 = [os.path.join(f.parents[0],'Mirror'+f.name) for f in Xfiles2] # creat a same as files but with Mirror added to the file names
Mainfolders =  [os.path.join(f.parents[0],f.stem[:-1]) for f in Xfiles2]
print(Xfiles3)
XfilesL = [os.path.join(Mainfolder,f) for f in os.listdir(Mainfolder) if f.endswith('L.avi') and not f.startswith('Mask')] # find all files with R.avi as file name
Xfiles2 = [Path(f) for f in XfilesL] # make each file name path to extract the parents and anme
Xfiles4 = [os.path.join(f.parents[0],'Mask'+f.name) for f in Xfiles2] # creat a same as files but with Mirror added to the file names
print(Xfiles4)



def Mask(frame2,sigma):
    import numpy as np
    [x1,x2,x3]=frame2.shape;
    center = [x1 ,x1/2]
    x = np.arange(0, size, 1, float)
    y = x[:,np.newaxis]

    if center is None:
        x0 = y0 = size // 2
    else:
        x0 = center[0]
        y0 = center[1]

    g=np.exp(-4*np.log(2) * ((x-x0)**2 + (y-y0)**2) / sigma**2) 
    g=np.delete(g, list(range(x1-x2)), 1)

    y = np.expand_dims(g, axis=3)
    y=np.repeat(y,3,axis=2)
    a = np.array(frame2, dtype=float)
    a = a*(1-y)
    img = a.astype(np.uint8)

    return(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-73562cd595d5> in <module>()
#       4 from IPython.display import clear_output
#       5 clear_output(wait=True)
# ----> 6 Xfiles = [os.path.join(Mainfolder,f) for f in os.listdir(Mainfolder) if f.endswith('R.avi') and not f.startswith('Mirror')] # find all files with R.avi as file name
#       7 Xfiles2 = [Path(f) for f in Xfiles] # make each file name path to extract the parents and anme
#       8 Xfiles3 = [os.path.join(f.parents[0],'Mirror'+f.name) for f in Xfiles2] # creat a same as files but with Mirror added to the file names
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D:\\videos\\ar32\\2020_11_24\\'

# %%
Mainfolder = 'D:\\videos\\ar32\\2020_11_24\\'
from pathlib import Path
import os
from IPython.display import clear_output
clear_output(wait=True)
XfilesR = [os.path.join(Mainfolder,f) for f in os.listdir(Mainfolder) if f.endswith('R.avi') and not f.startswith('Mirror')] # find all files with R.avi as file name
Xfiles2 = [Path(f) for f in XfilesR] # make each file name path to extract the parents and anme
Xfiles3 = [os.path.join(f.parents[0],'Mirror'+f.name) for f in Xfiles2] # creat a same as files but with Mirror added to the file names
Mainfolders =  [os.path.join(f.parents[0],f.stem[:-1]) for f in Xfiles2]
print(Xfiles3)
XfilesL = [os.path.join(Mainfolder,f) for f in os.listdir(Mainfolder) if f.endswith('L.avi') and not f.startswith('Mask')] # find all files with R.avi as file name
Xfiles2 = [Path(f) for f in XfilesL] # make each file name path to extract the parents and anme
Xfiles4 = [os.path.join(f.parents[0],'Mask'+f.name) for f in Xfiles2] # creat a same as files but with Mirror added to the file names
print(Xfiles4)
# Out:
# ['D:\\videos\\ar32\\2020_11_24\\Mirror100R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror101R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror102R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror103R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror104R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror105R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror106R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror107R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror108R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror109R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror10R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror110R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror111R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror112R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror113R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror114R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror115R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror116R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror117R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror118R.avi', 'D:\\videos\\ar32\\2020_11_24\\Mirror1
# ...

# %%
# %%
# import numpy as np
# import matplotlib.pyplot as plt
#
# def makeGaussian(size, fwhm = 3, center=None):
#     """ Make a square gaussian kernel.
#
#     size is the length of a side of the square
#     fwhm is full-width-half-maximum, which
#     can be thought of as an effective radius.
#     """
#
#     x = np.arange(0, size, 1, float)
#     y = x[:,np.newaxis]
#
#     if center is None:
#         x0 = y0 = size // 2
#     else:
#         x0 = center[0]
#         y0 = center[1]
#
#     return np.exp(-4*np.log(2) * ((x-x0)**2 + (y-y0)**2) / fwhm**2)
#
# def Mask(frame2,sigma):
#     [x1,x2,x3]=frame2.shape;
#     g= makeGaussian(x1, sigma, [x1 ,x1/2]);
#     g=np.delete(g, list(range(x1-x2)), 1)
#
#     y = np.expand_dims(g, axis=3)
#     y=np.repeat(y,3,axis=2)
#     a = np.array(frame2, dtype=float)
#     a = a*(1-y)
#     img = a.astype(np.uint8)
#
#     return(img)

# %%
from PIL import Image
import numpy as np
import cv2 # this is important and is reading and writing images and video 
thisindex = 5
#video_name = Xfiles[thisindex];
#print(Xfiles3[thisindex])
enhancer=1.1
video_name = Xfiles[thisindex];
cap = cv2.VideoCapture(video_name)# reading the videofile
frame_width  = np.uint8(cap.get(3)) # float
frame_height = np.uint8(cap.get(4)) # float
fourcc = cv2.VideoWriter_fourcc('M','J','P','G')
ret, frame = cap.read()
height, width, layers = frame.shape
allstats = [];
out = cv2.VideoWriter(Xfiles3[thisindex],fourcc, 1,( height, width)) 
i = 0
while(cap.isOpened()):
 # Capture frame-by-frame
 ret, frame = cap.read()
 if ret == True:
  frame2 = cv2.flip(frame, 1) 
  #allstats.append(frame2[100,100][1])
  allstats.append(np.mean(frame2))

  frame2 = Mask(frame2,60)
  frame2 =frame2*enhancer
  i+=1
  numbers= allstats;
  numbers[:] = [1-number/100 for number in allstats]
  #allstats = np.mean(frame2)

 else:
  break
#
from PIL import Image
import numpy as np
import cv2 # this is important and is reading and writing images and video 
for thisindex,moviesind in enumerate(Xfiles):
    enhancer=1.1
    video_name = Xfiles[thisindex];
    cap = cv2.VideoCapture(video_name)# reading the videofile
    frame_width  = np.uint8(cap.get(3)) # float
    frame_height = np.uint8(cap.get(4)) # float
    fourcc = cv2.VideoWriter_fourcc('M','J','P','G')
    ret, frame = cap.read()
    height, width, layers = frame.shape

    out = cv2.VideoWriter(Xfiles3[thisindex],fourcc, 1,( height, width)) 
    i = 0
    while(cap.isOpened()):
     # Capture frame-by-frame
     ret, frame = cap.read()
     print(ret)
     if ret == True:
      frame2 = cv2.flip(frame, 1) 
      frame2 = Mask(frame2,60)
      frame2 =frame2*enhancer
      cv2.imwrite(os.path.join(Mainfolders[thisindex],'R_mirror'+str(i)+'.jpg'),frame2)
      i+=1
     else:
      break


    cap.release()
    out.release()
    cv2.destroyAllWindows()
    import os
    Mainfolder = Mainfolders[thisindex]
    files = [os.path.join(Mainfolder,f)  for f in os.listdir(Mainfolder) if f.startswith('R_mirror')] # add path to each file
    frame = cv2.imread(os.path.join(Mainfolder, files[0]))
    height, width, layers = frame.shape
    video = cv2.VideoWriter(Xfiles3[thisindex], 0, 40, (width,height))
    fps = 40
    files.sort(key=lambda x: os.path.getmtime(x))
    images = files
    for idx,image in enumerate(images):
    #worksheet.write_row( idx+1,col, mat)
        frame = cv2.imread(os.path.join(Mainfolder, images[idx]))
        video.write(frame)
    cv2.destroyAllWindows()
    video.release()

#Xfiles4= Xfiles4[156:];

from PIL import Image
import numpy as np
import cv2 # this is important and is reading and writing images and video 
for thisindex,moviesind in enumerate(Xfiles4):
    enhancer=1.1

    video_name = XfilesL[thisindex];
    cap = cv2.VideoCapture(video_name)# reading the videofile
    frame_width  = np.uint8(cap.get(3)) # float
    frame_height = np.uint8(cap.get(4)) # float
    fourcc = cv2.VideoWriter_fourcc('M','J','P','G')
    ret, frame = cap.read()
    height, width, layers = frame.shape

    out = cv2.VideoWriter(Xfiles4[thisindex],fourcc, 1,( height, width)) 
    i = 0
    while(cap.isOpened()):
     # Capture frame-by-frame
     ret, frame = cap.read()
     print(ret)
     if ret == True:
      frame2 =frame 
      frame2 = Mask(frame2,60)
      frame2 =frame2*enhancer

      cv2.imwrite(os.path.join(Mainfolders[thisindex],'Mask'+str(i)+'.jpg'),frame2)
      i+=1
     else:
      break


    cap.release()
    out.release()
    cv2.destroyAllWindows()
    import os
    Mainfolder = Mainfolders[thisindex]
    files = [os.path.join(Mainfolder,f)  for f in os.listdir(Mainfolder) if f.startswith('Mask')] # add path to each file
    frame = cv2.imread(os.path.join(Mainfolder, files[0]))
    height, width, layers = frame.shape
    video = cv2.VideoWriter(Xfiles4[thisindex], 0, 40, (width,height))
    fps = 40
    files.sort(key=lambda x: os.path.getmtime(x))
    images = files
    for idx,image in enumerate(images):
    #worksheet.write_row( idx+1,col, mat)
        frame = cv2.imread(os.path.join(Mainfolder, images[idx]))
        video.write(frame)
    cv2.destroyAllWindows()
    video.release()
# Out:
# C:\Users\Tennessee\Anaconda3\envs\dlc-windowsGPU\lib\site-packages\ipykernel_launcher.py:43: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
from PIL import Image
import numpy as np
import cv2 # this is important and is reading and writing images and video 
for thisindex,moviesind in enumerate(Xfiles):
    enhancer=1.1
    video_name = Xfiles[thisindex];
    cap = cv2.VideoCapture(video_name)# reading the videofile
    frame_width  = np.uint8(cap.get(3)) # float
    frame_height = np.uint8(cap.get(4)) # float
    fourcc = cv2.VideoWriter_fourcc('M','J','P','G')
    ret, frame = cap.read()
    height, width, layers = frame.shape

    out = cv2.VideoWriter(Xfiles3[thisindex],fourcc, 1,( height, width)) 
    i = 0
    while(cap.isOpened()):
     # Capture frame-by-frame
     ret, frame = cap.read()
     print(ret)
     if ret == True:
      frame2 = cv2.flip(frame, 1) 
      frame2 = Mask(frame2,60)
      frame2 =frame2*enhancer
      cv2.imwrite(os.path.join(Mainfolders[thisindex],'R_mirror'+str(i)+'.jpg'),frame2)
      i+=1
     else:
      break


    cap.release()
    out.release()
    cv2.destroyAllWindows()
    import os
    Mainfolder = Mainfolders[thisindex]
    files = [os.path.join(Mainfolder,f)  for f in os.listdir(Mainfolder) if f.startswith('R_mirror')] # add path to each file
    frame = cv2.imread(os.path.join(Mainfolder, files[0]))
    height, width, layers = frame.shape
    video = cv2.VideoWriter(Xfiles3[thisindex], 0, 40, (width,height))
    fps = 40
    files.sort(key=lambda x: os.path.getmtime(x))
    images = files
    for idx,image in enumerate(images):
    #worksheet.write_row( idx+1,col, mat)
        frame = cv2.imread(os.path.join(Mainfolder, images[idx]))
        video.write(frame)
    cv2.destroyAllWindows()
    video.release()

# %%
#Xfiles4= Xfiles4[156:];

from PIL import Image
import numpy as np
import cv2 # this is important and is reading and writing images and video 
for thisindex,moviesind in enumerate(Xfiles4):
    enhancer=1.1

    video_name = XfilesL[thisindex];
    cap = cv2.VideoCapture(video_name)# reading the videofile
    frame_width  = np.uint8(cap.get(3)) # float
    frame_height = np.uint8(cap.get(4)) # float
    fourcc = cv2.VideoWriter_fourcc('M','J','P','G')
    ret, frame = cap.read()
    height, width, layers = frame.shape

    out = cv2.VideoWriter(Xfiles4[thisindex],fourcc, 1,( height, width)) 
    i = 0
    while(cap.isOpened()):
     # Capture frame-by-frame
     ret, frame = cap.read()
     print(ret)
     if ret == True:
      frame2 =frame 
      frame2 = Mask(frame2,60)
      frame2 =frame2*enhancer

      cv2.imwrite(os.path.join(Mainfolders[thisindex],'Mask'+str(i)+'.jpg'),frame2)
      i+=1
     else:
      break


    cap.release()
    out.release()
    cv2.destroyAllWindows()
    import os
    Mainfolder = Mainfolders[thisindex]
    files = [os.path.join(Mainfolder,f)  for f in os.listdir(Mainfolder) if f.startswith('Mask')] # add path to each file
    frame = cv2.imread(os.path.join(Mainfolder, files[0]))
    height, width, layers = frame.shape
    video = cv2.VideoWriter(Xfiles4[thisindex], 0, 40, (width,height))
    fps = 40
    files.sort(key=lambda x: os.path.getmtime(x))
    images = files
    for idx,image in enumerate(images):
    #worksheet.write_row( idx+1,col, mat)
        frame = cv2.imread(os.path.join(Mainfolder, images[idx]))
        video.write(frame)
    cv2.destroyAllWindows()
    video.release()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# C:\Users\Tennessee\Anaconda3\envs\dlc-windowsGPU\lib\site-packages\ipykernel_launcher.py:43: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt 

def makeGaussian(size, fwhm = 3, center=None):
    """ Make a square gaussian kernel.

    size is the length of a side of the square
    fwhm is full-width-half-maximum, which
    can be thought of as an effective radius.
    """

    x = np.arange(0, size, 1, float)
    y = x[:,np.newaxis]

    if center is None:
        x0 = y0 = size // 2
    else:
        x0 = center[0]
        y0 = center[1]

    return np.exp(-4*np.log(2) * ((x-x0)**2 + (y-y0)**2) / fwhm**2)

def Mask(frame2,sigma):
    [x1,x2,x3]=frame2.shape;
    g= makeGaussian(x1, sigma, [x1 ,x1/2]);
    g=np.delete(g, list(range(x1-x2)), 1)

    y = np.expand_dims(g, axis=3)
    y=np.repeat(y,3,axis=2)
    a = np.array(frame2, dtype=float)
    a = a*(1-y)
    img = a.astype(np.uint8)

    return(img)


g= makeGaussian(20, 10, [20 ,10]);
plt.imshow(Mask(frame2,60), cmap ="Greens")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1f90788494d1> in <module>
#      36
#      37 g= makeGaussian(20, 10, [20 ,10]);
# ---> 38 plt.imshow(Mask(frame2,60), cmap ="Greens")
#      39 plt.show()
#
# NameError: name 'frame2' is not defined

# %%
[x1,x2,x3]=frame2.shape;
g= makeGaussian(x1, 50, [x1 ,x1/2]);
g=np.delete(g, list(range(x1-x2)), 1)

y = np.expand_dims(g, axis=3)
y=np.repeat(y,3,axis=2)
a = np.array(frame2, dtype=float)
a = a*(1-y)
img = a.astype(np.uint8)
frame2 = Mask(frame2,100)

plt.imshow(img, cmap ="gray")
plt.show()

# %%
import deeplabcut

# %%
Mainfolder = 'D:\\videos\\ar19\\2020_09_16'
Mainfolder = 'D:\\videos\\ar32\\2020_10_12'
Mainfolder = 'D:\\videos\\ar19\\2020_10_12'
Mainfolder = 'D:\\videos\\ar32\\2020_11_12'
path_config_file = 'D:\\videos\\ar32\\2020_10_09\\ar32_10_09_20LRwhiskers_4-Arash-2020-10-12\\config.yaml';
path_config_file = 'D:\\videos\\ar30\\2020_11_04\\ar30_11_05_20whiskers-Arash-2020-11-08\\config.yaml'

from pathlib import Path
import os


Xfiles = [os.path.join(Mainfolder,f) for f in os.listdir(Mainfolder) if f.endswith('L.avi') and not f.startswith('Mask') and not f.startswith('Mirror') ] # find all files with R.avi as file name
Xfiles2 = [Path(f) for f in Xfiles] # make each file name path to extract the parents and anme
Xfiles4 = [os.path.join(f.parents[0],'Mask'+f.name) for f in Xfiles2] # creat a same as files but with Mirror added to the file names
Mainfolders =  [os.path.join(f.parents[0],f.stem[:-1]) for f in Xfiles2]
Xfiles = [os.path.join(Mainfolder,f) for f in os.listdir(Mainfolder) if f.endswith('R.avi') and not f.startswith('Mask') and not f.startswith('Mirror') ] # find all files with R.avi as file name
Xfiles2 = [Path(f) for f in Xfiles] # make each file name path to extract the parents and anme
Xfiles3 = [os.path.join(f.parents[0],'Mirror'+f.name) for f in Xfiles2] # creat a same as files but with Mirror added to the file names
Mainfolders =  [os.path.join(f.parents[0],f.stem[:-1]) for f in Xfiles2]
print(Xfiles4)

text_files = Xfiles3;
scorername=deeplabcut.analyze_videos(path_config_file,text_files,shuffle=1, save_as_csv=True)
print(scorername)
deeplabcut.filterpredictions(path_config_file,text_files,shuffle=1)
text_files = Xfiles4;
scorername=deeplabcut.analyze_videos(path_config_file,text_files,shuffle=1, save_as_csv=True)
print(scorername)
deeplabcut.filterpredictions(path_config_file,text_files,shuffle=1)
